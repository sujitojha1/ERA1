# %% [markdown]
# ## Load Models & Modules

# %%
# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2

# %%
# Future print function
from __future__ import print_function

# Load modules/models from EVA course
# !git clone https://github.com/sujitojha1/ERA1 -q --quiet
# !mv ERA1/Session16/* .
# !rm -rf ERA1

print("Loaded Modules and Models")

# Installing Library
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet
# !pip install torchtext -q --quiet

# For inline matplotlib plotting
# %matplotlib inline
# Out:
# Loaded Modules and Models

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 64
cfg['preload'] = None

from train import train_model

import torch
torch.cuda.amp.autocast(enabled=True)

train_model(cfg)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using device: cuda
# Max length of source sentence: 471
# Max length of target sentence: 482
# Processing Epoch 00: 100%|██████████| 996/996 [03:39<00:00,  4.54it/s, loss=5.686]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: And as he wandered alone through thedarkness he would rack his memory and his reason with a minute searchthat should bring out the blazing truth.
#     TARGET: Et tout seul en errant par la nuit, il allait faire, dans ses souvenirs,dans sa raison, l'enquête minutieuse d'où résulterait l'éclatantevérité.
#  PREDICTED: Il était , il avait , il avait , il avait , il , il de la de la .
# --------------------------------------------------------------------------------
#     SOURCE: Vous ne devez point redouter de questions de ma part ; mais enfin l’argent peut-il vous être utile, le pouvoir peut-il vous servir ?
#     TARGET: You need not be afraid of any questions on my part; still, can money be of use to you, can power help you?
#  PREDICTED: " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " "
# --------------------------------------------------------------------------------
# Processing Epoch 01: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=4.798]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: I run to mine which is beneath it, and I behold a black mass pass before my eyes and fall into the water.
#     TARGET: Je cours à la mienne qui est au-dessous, et je vois passer devant mes yeux une masse noire qui tombe dans l’eau.
#  PREDICTED: Je me dans la main qui l ' , et je me sur la mer et les yeux de l ' eau .
# --------------------------------------------------------------------------------
#     SOURCE: "Gently!"
#     TARGET: —Doucement!
#  PREDICTED: -- !
# --------------------------------------------------------------------------------
# Processing Epoch 02: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=4.173]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: 'Settled, indeed!
#     TARGET: – Joliment établi.
#  PREDICTED: – , en effet !
# --------------------------------------------------------------------------------
#     SOURCE: "Do not bite me, monster!" she cried.
#     TARGET: « Ne me mords pas, monstre ! cria-t-elle.
#  PREDICTED: « Ne m ' pas , » s ' écria - t - elle .
# --------------------------------------------------------------------------------
# Processing Epoch 03: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=3.808]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: We've got to get there first, that's all."
#     TARGET: Il s'agit d'arriver premiers. Voilà tout. »
#  PREDICTED: Nous sommes là , c ' est tout à l ' abord , c ' est tout .
# --------------------------------------------------------------------------------
#     SOURCE: She had remained with naked shoulders, already over-mature, but still imposing and desirable, with the broad bust of a Ceres gilded by the autumn.
#     TARGET: Elle était restée les épaules nues, déja trop mure, mais éclatante et désirable encore, avec sa carrure de Céres dorée par l'automne.
#  PREDICTED: Elle était resté avec des épaules , déjà , mais , en plein d ’ une hauteur , , avec les grandes , dans l ’ automne .
# --------------------------------------------------------------------------------
# Processing Epoch 04: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=3.427]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Aramis came behind, giving his arm to Porthos.
#     TARGET: Aramis venait derrière donnant le bras à Porthos.
#  PREDICTED: Aramis entra derrière , tenant son bras à Porthos .
# --------------------------------------------------------------------------------
#     SOURCE: His soul fell into profound night.
#     TARGET: Cette âme tomba dans une nuit profonde.
#  PREDICTED: Son âme tomba dans l ’ âme profonde .
# --------------------------------------------------------------------------------
# Processing Epoch 05: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=3.109]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: La duchesse tenait le plus grand état de maison.
#     TARGET: The Duchessa lived in the greatest style imaginable.
#  PREDICTED: The Duchessa the most more than a house .
# --------------------------------------------------------------------------------
#     SOURCE: At seven dinner was served.
#     TARGET: À sept heures, on servit le dîner.
#  PREDICTED: À sept heures était servi .
# --------------------------------------------------------------------------------
# Processing Epoch 06: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=2.916]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Ah! There is a heart in which it is glorious to reign!'
#     TARGET: Ah! voilà un cœur dans lequel il est glorieux de régner!
#  PREDICTED: Ah ! c ’ est un cœur qui est beau !
# --------------------------------------------------------------------------------
#     SOURCE: Never before had she felt as if there were wool in her bones.
#     TARGET: Jamais elle ne s'était senti ainsi du coton dans les os.
#  PREDICTED: Jamais elle n ' avait trouvé plus devant lui , comme si il y avait de laine dans ses os .
# --------------------------------------------------------------------------------
# Processing Epoch 07: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=2.827]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: A dim, vague notion laid hold of my mind, but which was fast hardening into certainty.
#     TARGET: Une idée, d'abord vague, incertaine, se changeait en certitude dans mon esprit.
#  PREDICTED: Une pensée vague me soulagea , mais qui était vite à la certitude .
# --------------------------------------------------------------------------------
#     SOURCE: "Last night."
#     TARGET: --Hier au soir.
#  PREDICTED: -- Hier , c ' est la nuit .
# --------------------------------------------------------------------------------
# Processing Epoch 08: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=2.925]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "That's true.
#     TARGET: --Cela c'est vrai.
#  PREDICTED: -- C ' est vrai .
# --------------------------------------------------------------------------------
#     SOURCE: Then he pressed a button.
#     TARGET: Puis, il pressa un bouton.
#  PREDICTED: Alors il serra une .
# --------------------------------------------------------------------------------
# Processing Epoch 09: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=2.784]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He embraced her, and lay down beside her, waiting till she was able to walk.
#     TARGET: Il l'embrassa, il se coucha pres d'elle, en attendant qu'elle put marcher.
#  PREDICTED: Il l ’ embrassa , et gisait à près d ’ elle , attendant qu ’ elle put marcher .
# --------------------------------------------------------------------------------
#     SOURCE: "And ask at the station office if there is a message for me."
#     TARGET: – Et demandez au chef de gare s’il y a un message pour moi. »
#  PREDICTED: -- Et , à la gare , s ' il y a un mot pour moi .
# --------------------------------------------------------------------------------
# Processing Epoch 10: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=2.481]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Only it had the inconvenience of necessitating the sacrifice of a piece of handkerchief.
#     TARGET: Seulement, il avait l'inconvénient de nécessiter le sacrifice d'un morceau de mouchoir.
#  PREDICTED: Seulement , ce soit le sacrifice d ' , le sacrifice d ' un fichu de fichu .
# --------------------------------------------------------------------------------
#     SOURCE: "Ah, good, then," replied Athos, "we will teach them, these door breakers!"
#     TARGET: -- Ah! bon! alors, dit Athos, nous allons les travailler, ces enfonceurs de portes.»
#  PREDICTED: -- Ah ! alors , répondit Athos , nous les , ces vagues vagues !
# --------------------------------------------------------------------------------
# Processing Epoch 11: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=2.435]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Perhaps we shall be more fortunate if we follow the western tunnel."
#     TARGET: Il est possible que nous soyons plus heureux en suivant le tunnel de l'ouest.»
#  PREDICTED: Peut - être rencontrerons - nous plus heureux que nous nous nous nous le tunnel soit porté .
# --------------------------------------------------------------------------------
#     SOURCE: My uncle lost no time in obeying the friendly call, nor was I slack in following.
#     TARGET: Mon oncle se hâta d'obéir à cette amicale injonction. Je le suivis.
#  PREDICTED: Mon oncle n ' avait pas le temps d ' obéir à l ' appel du désir affectueux , et je par la taille .
# --------------------------------------------------------------------------------
# Processing Epoch 12: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=2.232]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: There they disappeared in the hold.
#     TARGET: Là ils disparurent à fond de cale.
#  PREDICTED: Là , ils ont disparu dans la cale .
# --------------------------------------------------------------------------------
#     SOURCE: And I do not want a stranger--unsympathising, alien, different from me; I want my kindred: those with whom I have full fellow- feeling.
#     TARGET: Je ne veux pas d'un étranger qui serait différent de moi, et avec lequel je ne pourrais pas sympathiser.
#  PREDICTED: Et je ne veux pas une étrangère , , je une autre fois chez moi ; ces parents dont j ' ai du bon coeur .
# --------------------------------------------------------------------------------
# Processing Epoch 13: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=2.156]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "I have brought you another," said d’Artagnan.
#     TARGET: -- Je t'en amène un autre, dit d'Artagnan.
#  PREDICTED: -- Je vous en ai élevée , dit d ' Artagnan .
# --------------------------------------------------------------------------------
#     SOURCE: There was always something to be done.
#     TARGET: Là, il y avait toujours à travailler.
#  PREDICTED: Il y avait toujours quelque chose à faire .
# --------------------------------------------------------------------------------
# Processing Epoch 14: 100%|██████████| 996/996 [03:41<00:00,  4.50it/s, loss=2.026]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Oh, that IS nice," says the hostess.
#     TARGET: « Oh ! Que c’est aimable, dit l’hôtesse.
#  PREDICTED: -- C ' est gentil , dit l ' hôtesse .
# --------------------------------------------------------------------------------
#     SOURCE: Many gave them commissions, to prevent them forgetting themselves in public-houses.
#     TARGET: Beaucoup leur donnaient des commissions, pour les empecher de s'oublier dans les estaminets.
#  PREDICTED: Beaucoup les avaient contre eux , et les oublier en public .
# --------------------------------------------------------------------------------
# Processing Epoch 15: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.842]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: You know that I am sacrificing far more.
#     TARGET: Tu sais que je te sacrifie bien plus.
#  PREDICTED: Vous savez que je me beaucoup .
# --------------------------------------------------------------------------------
#     SOURCE: To the fire i'the blood.
#     TARGET: To the fire i’ the blood.
#  PREDICTED: Enfin le sang se paraît dans le sang .
# --------------------------------------------------------------------------------
# Processing Epoch 16: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.847]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: I have, therefore, deserved death, Gentlemen of the Jury.
#     TARGET: J’ai donc mérité la mort, messieurs les jurés.
#  PREDICTED: J ’ ai donc mérité la mort , Messieurs les jurés des « poètes .
# --------------------------------------------------------------------------------
#     SOURCE: "You shall have my leave to hold your tongue, Axel, but not to talk in that irrational way."
#     TARGET: --Il t'est permis de te taire, Axel, quand tu voudras déraisonner de la sorte.»
#  PREDICTED: -- Tu vas me laisser réfléchir à ton enfant , Axel , mais pour ne pas parler de son parti .
# --------------------------------------------------------------------------------
# Processing Epoch 17: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.802]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: It was the coral realm.
#     TARGET: C'était le royaume du corail.
#  PREDICTED: C ' était le patron .
# --------------------------------------------------------------------------------
#     SOURCE: "Then, captain," replied the sailor, "let us build a house on the edge of the lake.
#     TARGET: -- Alors, monsieur Cyrus, répondit le marin, construisons une maison sur les bords du lac.
#  PREDICTED: -- Eh ! Monsieur Cyrus , répondit le marin , une maison sur le bord du lac .
# --------------------------------------------------------------------------------
# Processing Epoch 18: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.710]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "No, not at all.
#     TARGET: —Non, pas du tout…
#  PREDICTED: -- Non , pas du tout .
# --------------------------------------------------------------------------------
#     SOURCE: When he was twelve years old his mother had her own way; he began lessons.
#     TARGET: À douze ans, sa mère obtint que l’on commençât ses études. On en chargea le curé.
#  PREDICTED: Quand il eut douze ans de son père sa mère l ' avait à son gré .
# --------------------------------------------------------------------------------
# Processing Epoch 19: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.720]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Twice he returned to the charge without extracting anything else but exasperated shrugs of the shoulder.
#     TARGET: Deux fois, il revint a la charge, sans tirer de lui autre chose que des haussements d'épaules exaspérés.
#  PREDICTED: Deux fois , il revint pour l ' engageait sans approuver leur bon coup d ' épaule .
# --------------------------------------------------------------------------------
#     SOURCE: Le lecteur trouve cette conversation longue ; pourtant nous lui faisons grâce de plus de la moitié ; elle se prolongea encore deux heures.
#     TARGET: The reader finds this conversation long: and yet we are sparing him more than half of it; it continued for two hours more.
#  PREDICTED: The reader may be very long ; or , we will be more pleasant enough , she imagined more at two o ' clock .
# --------------------------------------------------------------------------------
# Processing Epoch 20: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=1.686]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: The furniture of this drawing-room, all in stamped velvet, was alwaysshrouded in chair-covers.
#     TARGET: Le mobilier du salon, en velours frappé, était toujours recouvertde housses.
#  PREDICTED: Les meubles de ce salon , tout pleins de velours , se sur le fauteuil .
# --------------------------------------------------------------------------------
#     SOURCE: Her dull black eyes seemed like two fathomless holes, and through her parted lips could be perceived the rosy tint of the inside of her mouth.
#     TARGET: Ses yeux, d'un noir mat, semblaient deux trous sans fond, et, par ses lèvres entr'ouvertes, on apercevait des clartés roses dans sa bouche.
#  PREDICTED: Ses yeux éteints brillaient deux pas pour un abîme ; et , par ses lèvres , on apercevait la voie de l ’ intérieur de la bouche .
# --------------------------------------------------------------------------------
# Processing Epoch 21: 100%|██████████| 996/996 [03:41<00:00,  4.50it/s, loss=1.627]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Is it the gypsy at whom he is thus gazing?"
#     TARGET: Est-ce que c’est l’égyptienne qu’il regarde ainsi ? »
#  PREDICTED: – C ’ est l ’ égyptienne à qui il est ainsi ?
# --------------------------------------------------------------------------------
#     SOURCE: THE MYSTERIOUS MANOR
#     TARGET: LE DOMAINE MYSTÉRIEUX
#  PREDICTED: LE
# --------------------------------------------------------------------------------
# Processing Epoch 22: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.687]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: The young man jeered at his wife, and ordered her to embrace him.
#     TARGET: Le jeune homme raillait sa femme en lui ordonnant de l'embrasser.
#  PREDICTED: Le jeune homme la mit en sa femme et lui ordonna d ' aller l ' embrasser .
# --------------------------------------------------------------------------------
#     SOURCE: Milady seized the occasion.
#     TARGET: Milady saisit l'occasion.
#  PREDICTED: Milady saisit cette occasion .
# --------------------------------------------------------------------------------
# Processing Epoch 23: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.605]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: It was seven o'clock in the morning.
#     TARGET: Il était sept heures du matin.
#  PREDICTED: Il était sept heures du matin .
# --------------------------------------------------------------------------------
#     SOURCE: He repeated the question, with some surprise at her silence.
#     TARGET: Un peu surpris de son silence, il répéta sa question.
#  PREDICTED: Il répétait la question , avec surprise à son silence .
# --------------------------------------------------------------------------------
# Processing Epoch 24: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=1.567]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: But there was nothing like this appeared; but as we made nearer and nearer the shore, the land looked more frightful than the sea.
#     TARGET: Mais rien de tout cela n'apparaissait; mais à mesure que nous approchions de la rive, la terre nous semblait plus redoutable que la mer.
#  PREDICTED: Mais ce n ' était rien comme cela . Mais , comme nous nous nous et plus au rivage , l ' autre qu ' une mauvaise mer .
# --------------------------------------------------------------------------------
#     SOURCE: "Oh," said Milady, raising herself, "I defy you to find any tribunal which pronounced that infamous sentence against me.
#     TARGET: -- Oh! dit Milady en se levant, je défie de retrouver le tribunal qui a prononcé sur moi cette sentence infâme.
#  PREDICTED: « Oh ! dit Milady en se levant , je vous défie d ' entrer dans le tribunal que cette phrase contre moi .
# --------------------------------------------------------------------------------
# Processing Epoch 25: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=1.574]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "I am willing enough," said Maheu, at last convinced.
#     TARGET: —Moi, je veux bien, dit enfin Maheu convaincu.
#  PREDICTED: — Je veux bien , dit enfin Maheu , convaincu .
# --------------------------------------------------------------------------------
#     SOURCE: "Terribly anxious."
#     TARGET: -- Une hâte effroyable.
#  PREDICTED: -- Sans doute .
# --------------------------------------------------------------------------------
# Processing Epoch 26: 100%|██████████| 996/996 [03:40<00:00,  4.53it/s, loss=1.522]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: 'I know a good part of it.
#     TARGET: – J’en connais une bonne partie.
#  PREDICTED: – Je sais bien du moins une partie .
# --------------------------------------------------------------------------------
#     SOURCE: Étienne's anxiety increased.
#     TARGET: L'inquiétude d'Étienne croissait.
#  PREDICTED: L ' inquiétude d ' Étienne s ' élargissait .
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     440 with _open_zipfile_writer(f) as opened_zipfile:
# --> 441     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442     return
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:668, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     667 num_bytes = storage.nbytes()
# --> 668 zip_file.write_record(name, storage.data_ptr(), num_bytes)
#
# RuntimeError: [enforce fail at inline_container.cc:471] . PytorchStreamWriter failed writing file data/185: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 11
#       8 import torch
#       9 torch.cuda.amp.autocast(enabled=True)
# ---> 11 train_model(cfg)
#
# File /kaggle/working/train.py:302, in train_model(config)
#     300 # Save the model at the end of every epoch
#     301 model_filename = get_weights_file_path(config, f"{epoch:02d}")
# --> 302 torch.save({
#     303     'epoch': epoch,
#     304     'model_state_dict': model.state_dict(),
#     305     'optimizer_state_dict': optimizer.state_dict(),
#     306     'global_step': global_step
#     307 }, model_filename)
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:440, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     437 _check_save_filelike(f)
#     439 if _use_new_zipfile_serialization:
# --> 440     with _open_zipfile_writer(f) as opened_zipfile:
#     441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:291, in _open_zipfile_writer_file.__exit__(self, *args)
#     290 def __exit__(self, *args) -> None:
# --> 291     self.file_like.write_end_of_file()
#
# RuntimeError: [enforce fail at inline_container.cc:337] . unexpected pos 104554496 vs 104554384
