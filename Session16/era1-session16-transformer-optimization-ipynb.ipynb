# %% [markdown]
# ## Load Models & Modules

# %%
# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2

# %%
# Future print function
from __future__ import print_function

# Load modules/models from EVA course
# !git clone https://github.com/sujitojha1/ERA1 -q --quiet
# !mv ERA1/Session16/* .
# !rm -rf ERA1

print("Loaded Modules and Models")

# Installing Library
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet
# !pip install torchtext -q --quiet

# For inline matplotlib plotting
# %matplotlib inline
# Out:
# Loaded Modules and Models

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 64
cfg['preload'] = None

from train import train_model

import torch
torch.cuda.amp.autocast(enabled=True)

train_model(cfg)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using device: cuda
# Max length of source sentence: 471
# Max length of target sentence: 482
# Processing Epoch 00: 100%|██████████| 996/996 [03:46<00:00,  4.41it/s, loss=5.015]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: So the Tankadere kept steadily on her northward track.
#     TARGET: « Eh bien, oui ! Votre Honneur a raison.
#  PREDICTED: le capitaine Nemo , la porte de la porte .
# --------------------------------------------------------------------------------
#     SOURCE: This measure was distasteful to me.
#     TARGET: Une semblable démarche me répugnait.
#  PREDICTED: Cette fois me me me me .
# --------------------------------------------------------------------------------
# Processing Epoch 01: 100%|██████████| 996/996 [03:38<00:00,  4.56it/s, loss=4.521]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Francs!" Conseil rebuked.
#     TARGET: -- De francs ! reprit Conseil.
#  PREDICTED: -- ! » s ' écria Conseil .
# --------------------------------------------------------------------------------
#     SOURCE: The descent had begun, and the few strikers from the Deux-Cent-Quarante settlement who had been posted as scouts had not yet warned their mates.
#     TARGET: La descente commençait, les quelques grévistes du coron des Deux-Cent-Quarante, postés en éclaireurs, hésitaient a prévenir les camarades.
#  PREDICTED: La lumière avait été et les de quelques instants qui avaient été qui n ' avait pas été encore .
# --------------------------------------------------------------------------------
# Processing Epoch 02: 100%|██████████| 996/996 [03:38<00:00,  4.56it/s, loss=3.823]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He counted twelve people seated round the green cloth.
#     TARGET: Il compta douze personnes assises autour du tapis vert.
#  PREDICTED: Il comptait douze gens assis sur le drap de la toile .
# --------------------------------------------------------------------------------
#     SOURCE: 'Hark ye, sister,' says he, 'where is this sick woman?
#     TARGET: --Écoute, ma soeur, dit-il, où donc est cette femme malade?
#  PREDICTED: -- Écoutez , ma soeur , dit - il , où est cette femme ?
# --------------------------------------------------------------------------------
# Processing Epoch 03: 100%|██████████| 996/996 [03:39<00:00,  4.54it/s, loss=3.859]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "What! will you--"
#     TARGET: -- Comment, vous voulez...
#  PREDICTED: -- Comment !
# --------------------------------------------------------------------------------
#     SOURCE: They hardly allowed themselves a moment's repose, and the glare of the flames which shot from the crater enabled them to work night and day.
#     TARGET: À peine prenaient-ils quelque repos, et l'éclat des flammes qui jaillissaient du cratère leur permettait de continuer nuit et jour.
#  PREDICTED: Ils ne se laissa pas un instant de repos , et l ' éclat de la flamme qui les du cratère et jour .
# --------------------------------------------------------------------------------
# Processing Epoch 04: 100%|██████████| 996/996 [03:39<00:00,  4.53it/s, loss=2.610]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: To prolong doubt was to prolong hope.
#     TARGET: Prolonger le doute, c'était prolonger l'espoir.
#  PREDICTED: Pour se prolonger !
# --------------------------------------------------------------------------------
#     SOURCE: If you were to stand at night by the sea-shore with Harris, and say: "Hark! do you not hear?
#     TARGET: Si, d’aventure, un soir, vous vous trouviez au bord de la mer avec Harris et lui disiez : « Chut !
#  PREDICTED: Si vous feriez la nuit à la mer avec Harris avec Harris , et dites : -- écoutez - vous !
# --------------------------------------------------------------------------------
# Processing Epoch 05: 100%|██████████| 996/996 [03:38<00:00,  4.55it/s, loss=3.288]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: People talk of natural sympathies; I have heard of good genii: there are grains of truth in the wildest fable.
#     TARGET: Le peuple parle de sympathies naturelles et de bons génies; il y a du vrai dans les fables les plus bizarres.
#  PREDICTED: On en voit , je l ' ai entendu parler de bon , et il y a de la vérité , dans la grande fable de la fable .
# --------------------------------------------------------------------------------
#     SOURCE: His father was promptly convinced.
#     TARGET: Son père, aussitôt, fut convaincu:
#  PREDICTED: Son pere était promptement .
# --------------------------------------------------------------------------------
# Processing Epoch 06: 100%|██████████| 996/996 [03:38<00:00,  4.55it/s, loss=2.722]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He saw the Mayor's features resume their expression of embarrassment and ill humour.
#     TARGET: Il voyait la physionomie du maire reprendre l’expression de l’embarras et de l’humeur.
#  PREDICTED: Il vit le figure du maire , la figure du maire d ’ embarras et mal .
# --------------------------------------------------------------------------------
#     SOURCE: The following day, when the young couple came downstairs, Camille had still his sickly languidness, his righteous tranquillity of an egotist.
#     TARGET: Et, le lendemain, lorsque les jeunes époux descendirent, Camille avait encore sa langueur maladive, sa sainte tranquillité d'égoïste.
#  PREDICTED: Le lendemain , lorsqu ' il descendait descendait , Camille avait toujours son retour le mal de lui pour les .
# --------------------------------------------------------------------------------
# Processing Epoch 07: 100%|██████████| 996/996 [03:39<00:00,  4.54it/s, loss=2.437]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Come," said Catherine; "there's something for you.
#     TARGET: —Venez, dit Catherine, il y a quelque chose pour vous.
#  PREDICTED: — Voyons , dit Catherine , il y a quelque chose pour toi .
# --------------------------------------------------------------------------------
#     SOURCE: But no, Axel, I kept it for you."
#     TARGET: Mais non, Axel, je la réservais pour toi.
#  PREDICTED: Mais non , Axel , je l ' ai gardé .
# --------------------------------------------------------------------------------
# Processing Epoch 08: 100%|██████████| 996/996 [03:38<00:00,  4.55it/s, loss=2.389]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Her heart contracted.
#     TARGET: Son cœur se serra.
#  PREDICTED: Son coeur se contractèrent .
# --------------------------------------------------------------------------------
#     SOURCE: "And who?" asked M. de Treville.
#     TARGET: -- Et qui cela? demanda M. de Tréville.
#  PREDICTED: -- Et qui ? demanda M . de Tréville .
# --------------------------------------------------------------------------------
# Processing Epoch 09: 100%|██████████| 996/996 [03:38<00:00,  4.55it/s, loss=2.538]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "My dear Prudence, are you in want of any money?"
#     TARGET: Ma chère Prudence, avez-vous besoin d'argent?
#  PREDICTED: -- Mon cher Prudence , voulez - vous de l ' argent ?
# --------------------------------------------------------------------------------
#     SOURCE: Well, I have lived long enough to see that difference breeds hatred,' he said to himself one morning.
#     TARGET: Eh bien, j’ai assez vécu pour voir que différence engendre haine, se disait-il un matin.
#  PREDICTED: Eh bien ! j ’ ai vécu assez longtemps à voir cette différence - haine vint à lui - même .
# --------------------------------------------------------------------------------
# Processing Epoch 10: 100%|██████████| 996/996 [03:39<00:00,  4.55it/s, loss=2.414]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Whose, then?"
#     TARGET: -- Qui est-ce donc?
#  PREDICTED: -- À qui qui qui ?
# --------------------------------------------------------------------------------
#     SOURCE: This house is paved with enemies; think of the passionate hatred that Elisa has for me.'
#     TARGET: Cette maison est pavée d’ennemis ; songez à la haine passionnée qu’Élisa a pour moi.
#  PREDICTED: Cette maison est pavé de l ’ ennemis , en de la haine qui m ’ a pour moi .
# --------------------------------------------------------------------------------
# Processing Epoch 11: 100%|██████████| 996/996 [03:38<00:00,  4.56it/s, loss=1.909]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Because you delight in sacrifice."
#     TARGET: -- Parce que vous aimez à vous sacrifier.
#  PREDICTED: -- Parce que vous avez bonheur .
# --------------------------------------------------------------------------------
#     SOURCE: There was nothing more to be done but for each to take his place before the fog should be completely dissipated.
#     TARGET: Il ne s'agissait plus pour chacun que de prendre son poste avant que la brume se fût complètement dissipée.
#  PREDICTED: Il n ' y avait plus qu ' à se faire que pour se prendre encore sa place avant de la veille .
# --------------------------------------------------------------------------------
# Processing Epoch 12: 100%|██████████| 996/996 [03:38<00:00,  4.56it/s, loss=1.727]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "He's looking pretty bad.
#     TARGET: Il a l'air au plus mal.
#  PREDICTED: — Il cherche un joli garçon .
# --------------------------------------------------------------------------------
#     SOURCE: During this time Cyrus Harding, Spilett, and Neb, crawling behind the rocks, glided towards the future scene of combat.
#     TARGET: Pendant ce temps, Cyrus Smith, Gédéon Spilett et Nab, rampant le long des roches, se glissaient vers le futur théâtre du combat.
#  PREDICTED: Pendant cette temps Cyrus Smith , Spilett , et Nab , se glissait derriere les roches , se glissa vers l ' avenir de combat .
# --------------------------------------------------------------------------------
# Processing Epoch 13: 100%|██████████| 996/996 [03:38<00:00,  4.55it/s, loss=1.866]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Well?"
#     TARGET: -- Enfin?
#  PREDICTED: -- Eh bien ?
# --------------------------------------------------------------------------------
#     SOURCE: — Dans ce cas, allons examiner la chambre. »
#     TARGET: "Then let us go and look at the room."
#  PREDICTED: " In that case are going to examine the room ."
# --------------------------------------------------------------------------------
# Processing Epoch 14: 100%|██████████| 996/996 [03:38<00:00,  4.56it/s, loss=1.863]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: It was only then I remembered, on seeing once again this tall vase with its tragic history, that we had once dined and slept there in former days.
#     TARGET: Je me rappelai seulement alors, en revoyant ce grand vase à la tragique histoire, que nous avions dîné et couché là jadis.
#  PREDICTED: Ce fut seulement que je me , en voyant encore ce vase de son goûter que nous n ’ avions pas été le temps , a la première fois .
# --------------------------------------------------------------------------------
#     SOURCE: The priest tore out the buttons of his cassock with impatience: "Stream of words!
#     TARGET: Le prêtre arrachait d’impatience les boutons de sa soutane.
#  PREDICTED: Le prêtre , il beau bien de sa soutane avec des mots : « des mots !
# --------------------------------------------------------------------------------
# Processing Epoch 15: 100%|██████████| 996/996 [03:39<00:00,  4.54it/s, loss=1.752]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: An apple-charlotte meringue was overwhelmed with praise.
#     TARGET: Une charlotte de pommes meringuée fut comblée d'éloges.
#  PREDICTED: Une pomme de distance était atterrée .
# --------------------------------------------------------------------------------
#     SOURCE: "I have been an idiot!" he thought, "and this man will see it.
#     TARGET: « J'ai été inepte ! pensait-il. L'autre lui aura appris qui j'étais !
#  PREDICTED: « J ’ ai été un idiot , pensait - il , et cet homme le voit .
# --------------------------------------------------------------------------------
# Processing Epoch 16: 100%|██████████| 996/996 [03:38<00:00,  4.55it/s, loss=1.672]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "They, too!"
#     TARGET: —Eux aussi!
#  PREDICTED: -- Ils sont trop !
# --------------------------------------------------------------------------------
#     SOURCE: The face resembled Camille.
#     TARGET: La figure ressemblait à Camille.
#  PREDICTED: La figure ressemblait à Camille .
# --------------------------------------------------------------------------------
# Processing Epoch 17: 100%|██████████| 996/996 [03:38<00:00,  4.55it/s, loss=1.658]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: Then Chaval, without growing angry at these jokes, turned on her.
#     TARGET: Alors, Chaval, sans se fâcher de ces rires, retomba sur elle.
#  PREDICTED: Alors , Chaval , sans se fâcher , se tourna vers elle .
# --------------------------------------------------------------------------------
#     SOURCE: "Dancing?" repeated Emma.
#     TARGET: -- Danser? reprit Emma.
#  PREDICTED: -- - vous ? répétait Emma .
# --------------------------------------------------------------------------------
# Processing Epoch 18: 100%|██████████| 996/996 [03:39<00:00,  4.54it/s, loss=1.696]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: It took us some time to pass through, as we were the only boat, and it is a big lock.
#     TARGET: Cela nous prit un certain temps, car nous étions l’unique bateau, et c’est une grande écluse.
#  PREDICTED: On nous donna un temps de passer , car nous étions le canot , une grande écluse .
# --------------------------------------------------------------------------------
#     SOURCE: Radiant palace—reared its head.
#     TARGET: —Un rayonnant palais—dressait son front.
#  PREDICTED: L ’ palais , la tête .
# --------------------------------------------------------------------------------
# Processing Epoch 19: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.794]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "What the devil would you have me do with that?" said the Englishman.
#     TARGET: «Et que diable voulez-vous que je fasse de cela? dit l'Anglais.
#  PREDICTED: -- Et que diable m ' auriez - vous de cet Anglais ? dit l ' Anglais .
# --------------------------------------------------------------------------------
#     SOURCE: Have I not felt it over Amanda's lover?
#     TARGET: Ne l’ai-je pas éprouvé pour l’amant d’Amanda!
#  PREDICTED: Ne l ’ ai - je pas senti Amanda ?
# --------------------------------------------------------------------------------
# Processing Epoch 20: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.599]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: You will find a few notes upon the matter under the heading B in my indexed list of cases."
#     TARGET: Vous trouverez quelques notes sur l’affaire à la lettre B de mes dossiers.
#  PREDICTED: Vous verrez quelques notes sur l ' Vois , sous la direction de mon , d ' une .
# --------------------------------------------------------------------------------
#     SOURCE: Even that is bad enough.
#     TARGET: Ce n’est surement pas l’idéal.
#  PREDICTED: Ça y est assez fâcheux .
# --------------------------------------------------------------------------------
# Processing Epoch 21: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=1.523]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Very well; let the complainants come in."
#     TARGET: -- Bien ! faites entrer les plaignants. »
#  PREDICTED: -- Eh bien ! que la venue .
# --------------------------------------------------------------------------------
#     SOURCE: He saw the Mayor's features resume their expression of embarrassment and ill humour.
#     TARGET: Il voyait la physionomie du maire reprendre l’expression de l’embarras et de l’humeur.
#  PREDICTED: Il vit les traits du maire tout tenter l ’ air de figure et de malade .
# --------------------------------------------------------------------------------
# Processing Epoch 22: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.558]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: 'But hark ye,' says his brother, 'are you in earnest? Do you really love this girl?
#     TARGET: Mais écoute, reprend-il, est-ce sérieux? aimes-tu vraiment la fille?
#  PREDICTED: -- Écoutez Écoutez ! dit son frère , êtes - vous sérieux , et mon amour !
# --------------------------------------------------------------------------------
#     SOURCE: "Is it a nickname?" asked Étienne, astonished.
#     TARGET: —C'est un surnom? demanda Étienne étonné.
#  PREDICTED: — C ' est ça , nom de roi ? demanda Étienne en s ' étonna .
# --------------------------------------------------------------------------------
# Processing Epoch 23: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.534]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "It is the last revolt of his wild nature," said he, "which remorse has touched, and which renewed solitude will terrify."
#     TARGET: «C'est la dernière révolte de cette rude nature, disait-il, que le remords a touchée et qu'un nouvel isolement épouvanterait.»
#  PREDICTED: -- C ' est la dernière révolte de son âme sauvage , dit - il , ce qui a touché , et qui aura une autre pour effrayer .
# --------------------------------------------------------------------------------
#     SOURCE: I would not now have exchanged Lowood with all its privations for Gateshead and its daily luxuries.
#     TARGET: Je n'aurais pas changé Lowood et toutes ses privations pour Gateshead et son luxe.
#  PREDICTED: Je n ' aurais jamais à Lowood avec toute sa under - de ses délices .
# --------------------------------------------------------------------------------
# Processing Epoch 24: 100%|██████████| 996/996 [03:40<00:00,  4.52it/s, loss=1.454]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: "Why, nephew," said he, "you look as if you were walking behind my coffin.
#     TARGET: -- Eh bien! mon neveu, dit-il, on dirait que vous marchez derrière mon cercueil.
#  PREDICTED: -- Mais , mon neveu , dit - il , tu regard comme si tu étais de me pres de moi .
# --------------------------------------------------------------------------------
#     SOURCE: Then a sudden idea crossed the mind of d’Artagnan.
#     TARGET: Alors une idée subite traversa l'esprit de d'Artagnan.
#  PREDICTED: Puis , une idée traversa subitement l ' esprit d ' Artagnan .
# --------------------------------------------------------------------------------
# Processing Epoch 25: 100%|██████████| 996/996 [03:39<00:00,  4.53it/s, loss=1.529]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: But the next instant I perceived that he held a round glass in the front of it, which magnified it in this fashion.
#     TARGET: Mais bientôt, je m'aperçus qu'il avait placé par- devant un verre rond qui le grossissait de cette manière.
#  PREDICTED: Mais le voisin de ce qu ’ il me fit tenir en ce verre , devant elle , qui le les connu à cette mode .
# --------------------------------------------------------------------------------
#     SOURCE: Near him an old soldier, with tanned skin and stripes won in twenty campaigns, had grown pale when he saw his bayonet twisted like a straw.
#     TARGET: Pres de lui, un vieux chevronné, au cuir tanné par vingt campagnes, avait blemi, quand il avait vu sa baionnette tordue comme une paille.
#  PREDICTED: Vers lui un vieux soldat , la peau rouge et gagné sur les vingt campagnes , avait en voyant le ventre tordu , comme un La paille .
# --------------------------------------------------------------------------------
# Processing Epoch 26: 100%|██████████| 996/996 [03:39<00:00,  4.53it/s, loss=1.454]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: But there was nothing.
#     TARGET: Mais il n'y avait rien.
#  PREDICTED: Mais il n ' y avait rien .
# --------------------------------------------------------------------------------
#     SOURCE: "At Queue−en−Brie."
#     TARGET: – À Queue-en-Brie. »
#  PREDICTED: – À of his Brie !
# --------------------------------------------------------------------------------
# Processing Epoch 27: 100%|██████████| 996/996 [03:39<00:00,  4.53it/s, loss=1.452]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: A terrible cry of anguish burst from me.
#     TARGET: Quel cri terrible m'échappa!
#  PREDICTED: Un cri terrible d ' angoisse éclata de moi .
# --------------------------------------------------------------------------------
#     SOURCE: My life is nothing more than a sequence of hypocrisies, because I have not an income of a thousand francs with which to buy my bread.'
#     TARGET: Ma vie n’est qu’une suite d’hypocrisies, parce que je n’ai pas mille francs de rente pour acheter du pain.
#  PREDICTED: Ma vie n ’ est rien plus qu ’ une suite d ’ , parce que je n ’ ai pas revenu à mon pain et le pain .
# --------------------------------------------------------------------------------
# Processing Epoch 28: 100%|██████████| 996/996 [03:39<00:00,  4.53it/s, loss=1.499]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: But fasting, prayer, study, the mortifications of the cloister, rendered my soul mistress of my body once more, and then I avoided women.
#     TARGET: Mais le jeûne, la prière, l’étude, les macérations du cloître, avaient refait l’âme maîtresse du corps. Et puis, j’évitais les femmes.
#  PREDICTED: Mais son , prier , le cloître , l ’ âme du cloître , ma maîtresse de mon corps encore et je évitèrent de femmes .
# --------------------------------------------------------------------------------
#     SOURCE: And that was the last that I was ever to see of Cousin Edie.
#     TARGET: C'était la dernière fois que je devais voir la cousine Edie.
#  PREDICTED: Et c ' était la dernière que j ' étais à voir du cousin Edie .
# --------------------------------------------------------------------------------
# Processing Epoch 29: 100%|██████████| 996/996 [03:40<00:00,  4.51it/s, loss=1.456]
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: He was another man.
#     TARGET: C’était un autre homme.
#  PREDICTED: Il était un autre homme .
# --------------------------------------------------------------------------------
#     SOURCE: In fact, tightly held as he was, Lubin endeavored still to cry out.
#     TARGET: En effet, tout comprimé qu'il était, Lubin essayait encore de filer des sons.
#  PREDICTED: En effet , dans d ' ailleurs , il était Lubin encore .
# --------------------------------------------------------------------------------
